# %% [markdown]
# <a href="https://colab.research.google.com/github/Dipesh360-wq/Assignment/blob/main/Handling_imbalance_data_set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Handling imbalance data set
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('creditcard.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124861 entries, 0 to 124860
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    124861 non-null  int64
#  1   V1      124861 non-null  float64
#  2   V2      124861 non-null  float64
#  3   V3      124861 non-null  float64
#  4   V4      124860 non-null  float64
#  5   V5      124860 non-null  float64
#  6   V6      124860 non-null  float64
#  7   V7      124860 non-null  float64
#  8   V8      124860 non-null  float64
#  9   V9      124860 non-null  float64
#  10  V10     124860 non-null  float64
#  11  V11     124860 non-null  float64
#  12  V12     124860 non-null  float64
#  13  V13     124860 non-null  float64
#  14  V14     124860 non-null  float64
#  15  V15     124860 non-null  float64
#  16  V16     124860 non-null  float64
#  17  V17     124860 non-null  float64
#  18  V18     124860 non-null  float64
#  19  V19     124860 non-null  float64
# ...

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df=df.drop(['V22'],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124861 entries, 0 to 124860
# Data columns (total 30 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    124861 non-null  int64
#  1   V1      124861 non-null  float64
#  2   V2      124861 non-null  float64
#  3   V3      124861 non-null  float64
#  4   V4      124860 non-null  float64
#  5   V5      124860 non-null  float64
#  6   V6      124860 non-null  float64
#  7   V7      124860 non-null  float64
#  8   V8      124860 non-null  float64
#  9   V9      124860 non-null  float64
#  10  V10     124860 non-null  float64
#  11  V11     124860 non-null  float64
#  12  V12     124860 non-null  float64
#  13  V13     124860 non-null  float64
#  14  V14     124860 non-null  float64
#  15  V15     124860 non-null  float64
#  16  V16     124860 non-null  float64
#  17  V17     124860 non-null  float64
#  18  V18     124860 non-null  float64
#  19  V19     124860 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Time             V1             V2             V3  \
# count  124861.000000  124861.000000  124861.000000  124861.000000
# mean    48422.610431      -0.252468      -0.002566       0.676188
# std     19461.728774       1.832905       1.630974       1.285598
# min         0.000000     -56.407510     -72.715728     -33.680984
# 25%     36261.000000      -1.021586      -0.580148       0.172435
# 50%     50262.000000      -0.263988       0.093240       0.751059
# 75%     64524.000000       1.156211       0.760756       1.371073
# max     77449.000000       1.960497      18.902453       9.382558
#
#                   V4             V5             V6             V7  \
# count  124860.000000  124860.000000  124860.000000  124860.000000
# mean        0.151837      -0.282740       0.085256      -0.114835
# std         1.331903       1.324604       1.289583       1.182771
# min        -5.172595     -42.147898     -26.160506     -31.764946
# ...

# %%
class_counts=df['Class'].value_counts()
print(class_counts)
import matplotlib.pyplot as plt
plt.figure(figsize=(4,3))
plt.bar(class_counts.index,class_counts.values)
plt.xlabel('Class')
plt.ylabel('Count')
plt.title('Distribution of Class')
plt.show()
# Out:
# Class
# 0.0    124601
# 1.0       259
# Name: count, dtype: int64

# %%
print(df.isnull().sum())
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        1
# V5        1
# V6        1
# V7        1
# V8        1
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
for column in df.columns:
    if df[column].isnull().any():
        df[column].fillna(df[column].mean(),inplace=True)
print(df.isnull().sum())
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
print(df['Class'].value_counts())
# Out:
# Class
# 0.000000    124601
# 1.000000       259
# 0.002074         1
# Name: count, dtype: int64

# %%
df.tail()
# Out:
#          Time        V1        V2        V3        V4        V5        V6  \
# 124856  77448 -0.835868  0.673600  1.904021 -0.263201  0.351435  0.236937
# 124857  77448 -2.817937 -0.107162  0.402607 -0.980962  0.682698  0.980801
# 124858  77449 -1.262504  1.434804  0.290138 -0.436888  0.801078  0.380510
# 124859  77449  1.087845  0.522904  0.275704  2.474583  0.213114 -0.225345
# 124860  77449  1.181458 -0.125634  0.454633  0.151837 -0.282740  0.085256
#
#               V7        V8        V9  ...       V20       V21       V23  \
# 124856  0.223675  0.334808 -0.232802  ... -0.240106  0.114441 -0.105240
# 124857  0.117625  1.387942 -0.779965  ... -0.458705  0.280573 -0.374319
# 124858  0.399066  0.554237 -0.531654  ... -0.190611  0.195197 -0.281029
# 124859  0.389247 -0.100848 -0.960723  ... -0.091763  0.007535 -0.061887
# 124860 -0.114835  0.061941 -0.084974  ...  0.042852 -0.036051 -0.034675
#
#              V24       V25       V26       V27       V28      Amount     Class
# ...

# %%
df=df.drop(df.index[124860])

# %%
df.tail()
# Out:
#          Time        V1        V2        V3        V4        V5        V6  \
# 124855  77448 -0.358736  1.088973  1.182810 -0.134401  0.274668 -0.469507
# 124856  77448 -0.835868  0.673600  1.904021 -0.263201  0.351435  0.236937
# 124857  77448 -2.817937 -0.107162  0.402607 -0.980962  0.682698  0.980801
# 124858  77449 -1.262504  1.434804  0.290138 -0.436888  0.801078  0.380510
# 124859  77449  1.087845  0.522904  0.275704  2.474583  0.213114 -0.225345
#
#               V7        V8        V9  ...       V20       V21       V23  \
# 124855  0.604681  0.085536 -0.659111  ...  0.143325 -0.232968 -0.075680
# 124856  0.223675  0.334808 -0.232802  ... -0.240106  0.114441 -0.105240
# 124857  0.117625  1.387942 -0.779965  ... -0.458705  0.280573 -0.374319
# 124858  0.399066  0.554237 -0.531654  ... -0.190611  0.195197 -0.281029
# 124859  0.389247 -0.100848 -0.960723  ... -0.091763  0.007535 -0.061887
#
#              V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
from imblearn.under_sampling import NearMiss
x=df.drop('Class',axis=1)
y=df['Class']
nm=NearMiss()
x_resampled,y_resampled=nm.fit_resample(x,y)
print(pd.Series(y_resampled).value_counts())
# Out:
# Class
# 0.0    259
# 1.0    259
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import RandomOverSampler
x=df.drop('Class',axis=1)
y=df['Class']
ros=RandomOverSampler()
x_resampled,y_resampled=ros.fit_resample(x,y)
print(pd.Series(y_resampled).value_counts())
# Out:
# Class
# 0.0    124601
# 1.0    124601
# Name: count, dtype: int64
